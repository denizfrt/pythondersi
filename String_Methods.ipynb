# %% [markdown]
# <a href="https://colab.research.google.com/github/denizfrt/pythondersi/blob/master/String_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # String Yöntemleri
#
#
# String sınıfı, Python ve genel olarak programlama dillerinde en çok kullanılan sınıflardan biridir. Hayatı kolaylaştırmak için birçok yerleşik yöntem zaten mevcuttur. Bu alıştırmadaki hedefiniz şunlar olacaktır:
#
#
# - Python belgelerini kullanarak doğru yöntemi aramayı öğrenmek
#
#
# Bunun için Google Colab not defterlerini kullanacağız, çünkü colab'ın her hücresi kodumuzu yorumlayabilir ve çalıştırıldığında sonuçları yazdırabilir. Bu, çalışmanızı ilerledikçe görebilmenizi sağlar.
#
#
# - Her hücre, kullanıcı tarafından yazılan kodu okur; bu kod, "Hello", 2+2, "hello".upper() gibi herhangi bir geçerli Python ifadesi olabilir.
# - Çalıştırıldığında bu kodun sonucunu değerlendirir.
# - Sonucu yazdırır.

# %%
# Let's try running this cell and take a look at the output
1 + 1
# Out:
# 2

# %% [markdown]
# Daha karmaşık bir örnek nasıl olur?
#
#
# Python'da her şey (dize, tamsayı, kayan sayı, liste...) bir **nesne**'dir. Bu nesneler üzerinde **yöntemler** çağırabiliriz. Bu tür yöntemler, yalnızca **sınıf** örnekleri üzerinde çağrılabildikleri için **örnek yöntemler** olarak adlandırılır. Yöntemi çağırdığımız nesneye alıcı denir.
#
#
# Fonksiyon ve yöntem arasındaki fark hakkında daha fazla bilgiyi [burada](https://www.tutorialspoint.com/difference-between-method-and-function-in-python) bulabilirsiniz.
#
#
# Python'da birçok yararlı yöntem vardır, ancak bugün, bir yöntemin `str` sınıfındaki bir nesne üzerinde nasıl etki edeceğini öğrenerek başlayacağız.
#
#
# `str` nedir? Python'da bir dizge türüyle çalışırken, bu dizge aslında bir nesnedir ve bu nesne `str` sınıfının bir örneğidir. `str` sınıfı, dizgeleri işlemek ve dönüştürmek için yararlı olan birçok varsayılan yöntemle ilişkilidir!
#
#
# Bazı yöntemler dizgiyi tamamen büyük harfe çevirir; bazıları dizgiyi belirli bir noktada böler; bazıları ise belirli karakterleri diğerleriyle değiştirir. Python'da bir dizgi nesnesi oluşturduğumuzda, tüm bu yöntemler otomatik olarak ona atanır, bu da o dizgiyi hızlı ve kolay bir şekilde işlememizi sağlar!
#
#
# Kafanız mı karıştı? Endişelenmeyin, Python ile ilk gününüz! Bu çok fazla bilgi ve henüz hepsini anlamanız beklenmiyor 😉
#
#
# Aşağıdaki hücreyi kullanarak, `str` sınıfı için `lower` yöntemini anlamamıza nasıl **yardımcı** olabileceğini görelim.

# %%
# help, I want to use a method for a string object, but I'm not sure how it works
help(str.lower)
# Out:
# Help on method_descriptor:
#
# lower(self, /) unbound builtins.str method
#     Return a copy of the string converted to lowercase.

# %% [markdown]
# ## String Yöntemleri Belgeleri
#
#
# String sınıfının doğru Python yöntemlerini bulun ve doğru cevapları bulana kadar örneklerimizle deneyin.
#
#
# Kod yazmak, yaratıcı olmak ve ihtiyacınız olan bilgiyi nasıl ve nerede arayacağınızı bilmekle ilgilidir! Çoğu zaman, en zor adım Google'a doğru soruyu sormaktır. Bu zorluk için ihtiyacınız olan yöntemleri bulmak için şunları kullanın:
#
#
# - Google ve [Stack Overflow](http://stackoverflow.com/)
# - Aradığınız yöntemin genel bir fikrine sahipseniz, [python doc](https://docs.python.org/3)
#
#
# Bu görev için herhangi bir tür yapay zeka kullanmayın. Dokümantasyonu kullanmayı öğrenmek, programcıların geliştirmesi gereken hayati bir beceridir ve bu alıştırmanın amacı, bulmacanın parçalarını kendi başınıza bir araya getirmeyi öğrenmektir.
#
#
# Aradığınız yöntemi bulduğunuzu ve nasıl kullanılacağını bildiğinizi düşündüğünüzde, sağladığımız örnekleri kullanarak bu yöntemi bir şey üzerinde test edin! Deneme, yeni başlayanlar için çok önemli bir adımdır.

# %% [markdown]
# ### Tekrar sayısını sayma
#
#
# Bir string yöntemi kullanarak `c_substring`'in `c_string`'de kaç kez geçtiğini yazdırın.
#
#
# Sonuç `6` olmalıdır.

# %%
# use a string method to print how many times c_substring occurs in c_string
c_string = "000123000123"
c_substring = "0"

# %%
print(c_string.count(c_substring))
# Out:
# 6

# %% [markdown]
# ### Soru mu?
#
#
# d_string "?" ile bitiyorsa, bir string yöntemi kullanarak `True` yazdırın.
#
#
# Sonuç `True` olmalıdır.

# %%
# d_string "?" ile bitiyorsa True yazdırmak için bir string yöntemi kullanın
d_string = "How are you?"

# %%
if d_string.endswith("?"):
    print(True)
# Out:
# True

# %% [markdown]
# ### Çevresindeki boşlukları kaldır
#
#
# Bir string yöntemi kullanarak, başındaki ve sonundaki boşluklar kaldırılmış `" hey yo "` stringinin bir kopyasını yazdırın.
#
#
# Sonuç `"hey yo"` olmalıdır.

# %%
# use a string method to print a copy of the e_string with leading and trailing whitespaces removed
e_string = "  hey yo  "

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Değiştirme
#
#
# Bir dizge yöntemi kullanarak, eski harfi yeni harfle değiştirerek `"casanova"` dizgesinin bir kopyasını yazdırın.
#
#
# Sonuç `"cosonovo"` olmalıdır.

# %%
# use a string method to print a copy of the f_string with the new letter replacing the old one
f_string = "casanova"

# %%
print(f_string.replace("a","o"))
# Out:
# cosonovo

# %% [markdown]
# ### Virgül ekle
#
#
# Bir string yöntemi kullanarak `a_string` (`"John Peter Jude"`) dizgesini her isim virgülle ayrılmış şekilde yazdırın.
#
#
# Sonuç `"John, Peter, Jude"` olmalıdır.

# %%
# use a string method to print a copy of the following string with every word separated by a comma
a_string = "John Peter Jude"

# %%
print(",".join(a_string.split()))
# Out:
# John,Peter,Jude

# %% [markdown]
# ### İçeriyor mu?
#
#
# `b_string` belirli bir `b_word` içeriyorsa `True` çıktısını veren bir yol bulun.
#
#
# Sonuç `True` olmalıdır.
#
#
# <details>
# <summary>İpucu</summary>
#
#
# Bu bir "yöntem" değildir, ancak bir stringi işleme koymanın bir yoludur!
#
#
# </details>

# %%
# use a string method to print True if the following string contains a certain word
b_string = "hey jude"
b_word = "jude"

# %%
if b_word in b_string:
  print("True")
# Out:
# True

# %% [markdown]
# ### Tam açıklama birleştirme
#
#
# `first_name` ve `last_name` büyük harfle yazılmış ve `age` birleştirme kullanılarak bir cümle yazdırın
#
#
# Sonuç `"John Doe 33 yaşında"` olmalıdır
#
#
# Bu, sadece string yöntemlerinden daha fazlasını gerektirir! İlk denemenizde, bir sonraki hücre için olan string enterpolasyonunu kullanmayın!
#
#
# <details>
# <summary>İpucu</summary>
#
#
# Stringleri birleştirebilirsiniz!
#
#
# `"Bruce" + ' ' + "Wayne"` = `"Bruce Wayne"`
#
#
# </details>

# %%
first_name = "john"
last_name = "doe"
age = "33"

# %%
print((first_name)+" "+(last_name)+" "+(age)+" "+"yaşında")
# Out:
# john doe 33 yaşında

# %% [markdown]
# ### Tam açıklama biçimlendirme
#
#
# Yukarıdakiyle aynı şeyi deneyin, ancak bu sefer string enterpolasyonu ile!
#
#
# <details>
# <summary>İpucu</summary>
#
#
# string enterpolasyonu bazen f string olarak adlandırılır, çünkü f ile başlaması gerekir (bu, eski bir enterpolasyon stilinden kalan `format` teriminin kalıntısıdır)!
#
#
# `f'{"Bruce"} {"Wayne"}'` = `"Bruce Wayne"`
#
#
# </details>

# %%
# Değişkenleri tekrar tanımlamamıza gerek yok, bunlar zaten mevcut ve orijinalleri dönüştürülmedi!
# Kanıt olarak, bunların büyük harfle yazılmadığını göstermek için burada yazdırıyoruz.
first_name, last_name, age

# %%
print(first_name.capitalize() + " " + last_name.capitalize() + " " + age + " yaşında")
# Out:
# John Doe 33 yaşında
